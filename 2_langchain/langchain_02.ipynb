# %%
from dotenv import load_dotenv
# API KEY 정보 불러오기
load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# %%
# 프롬프트
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "당신은 친절한 AI 어시스턴트입니다"),
        ("user", "#Question:\n{question}"),
    ]
)
# 모델
llm = ChatOpenAI(model_name="gpt-4o", temperature=0)
# 출력파서
output_parser = StrOutputParser()

# 체인생성
chain = prompt | llm | output_parser

# %%
user_input = "대한민국의 주요 관광지를 알려줘"

# %%
response = chain.invoke({"question": user_input})
print(response)
# Out:
# 대한민국에는 다양한 매력을 가진 관광지가 많이 있습니다. 여기 몇 가지 주요 관광지를 소개합니다:
#
# 1. **서울**: 대한민국의 수도로, 경복궁, 창덕궁, 북촌 한옥마을, 남산타워, 명동, 인사동 등 다양한 역사적, 문화적 명소가 있습니다.
#
# 2. **부산**: 해운대 해수욕장, 광안리 해수욕장, 자갈치 시장, 감천문화마을, 태종대 등 바다와 관련된 관광지가 많습니다.
#
# 3. **경주**: 신라 시대의 수도였던 경주는 불국사, 석굴암, 첨성대, 안압지 등 역사 유적지가 풍부합니다.
#
# 4. **제주도**: 한라산, 성산일출봉, 만장굴, 천지연 폭포, 협재 해수욕장 등 자연 경관이 아름다운 섬입니다.
#
# 5. **인천**: 송도 센트럴파크, 차이나타운, 월미도, 강화도 등 다양한 문화와 역사를 경험할 수 있습니다.
#
# 6. **전주**: 전주 한옥마을, 전주성당, 전주향교 등 전통과 현대가 어우러진 도시입니다.
#
# 7. **강릉**: 경포대, 주문진, 오죽헌, 정동진 등 동해안의 아름다운 해변과 자연을 즐길 수 있습니다.
#
# 8. **속초**: 설악산 국립공원, 속초해수욕장, 아바이마을 등 자연과 해산물을 즐길 수 있는 곳입니다.
#
# 이 외에도 대한민국에는 다양한 매력을 가진 도시와 관광지가 많으니, 여행 계획 시 관심 있는 지역을 더 탐색해 보세요!

# %% [markdown]
# ### 답변을 순차적으로 생성하여 보여주기

# %%
response = chain.stream({"question": user_input})
for token in response:
    print(token)
# Out:
# 대한
# 민국
# 에는
#  다양한
#  매
# 력을
#  가진
#  관광
# 지가
#  많이
#  있습니다
# .
#  여기
#  몇
#  가지
#  주요
#  관광
# 지를
#  소개
# 합니다
# :
#
#
# 1
# .
#  **
# 서울
# **
# :
#
#
#  -
#  **
# 경
# 복
# 궁
# **
# :
#  조
# 선
#  시대
# 의
#  대표
# 적인
#  궁
# 궐
# 로
# ,
#  한국
# 의
#  전
# 통
#  건
# 축
# 을
#  감
# 상
# 할
#  수
#  있습니다
# .
#
#
#  -
#  **
# 남
# 산
# 타
# 워
# (N
# 서울
# 타
# 워
# )**
# :
#  서울
# 의
#  전
# 경
# 을
#  한
# 눈
# 에
#  볼
#  수
#  있는
#  전망
# 대
# 입니다
# .
#
#
#  -
#  **
# 명
# 동
# **
# :
#  쇼
# 핑
# 과
#  다양한
#  먹
# 거
# 리를
#  즐
# 길
#  수
#  있는
#  번
# 화
# 가
# 입니다
# .
#
#
#  -
#  **
# 인
# 사
# 동
# **
# :
#  전
# 통
# 적인
#  한국
#  문
# 화를
#  체
# 험
# 할
#  수
#  있는
#  거리
# 로
# ,
#  다양한
#  전
# 통
#  공
# 예
# 품
# 과
#  갤
# 러
# 리가
#  있습니다
# .
#
#
# 2
# .
#  **
# 부
# 산
# **
# :
#
#
#  -
#  **
# 해
# 운
# 대
#  해
# 수
# 욕
# 장
# **
# :
#  한국
# 에서
#  가장
#  유명
# 한
#  해
# 변
#  중
#  하나
# 로
# ,
#  여
# 름
# 철
#  많은
#  관광
# 객
# 이
#  찾
# 습니다
# .
#
#
#  -
#  **
# 광
# 안
# 대
# 교
# **
# :
#  야
# 경
# 이
#  아름
# 다운
#  다
# 리
# 로
# ,
#  특히
#  밤
# 에
#  조
# 명이
#  켜
# 지
# 면
#  멋
# 진
#  경
# 관
# 을
#  제공합니다
# .
#
#
#  -
#  **
# 자
# 갈
# 치
#  시장
# **
# :
#  신
# 선
# 한
#  해
# 산
# 물을
#  맛
# 볼
#  수
#  있는
#  전
# 통
#  시장
# 입니다
# .
#
#
# 3
# .
#  **
# 경
# 주
# **
# :
#
#
#  -
#  **
# 불
# 국
# 사
# **
# :
#  유
# 네
# 스
# 코
#  세계
# 문화
# 유
# 산
# 으로
#  지정
# 된
#  사
# 찰
# 로
# ,
#  아름
# 다운
#  건
# 축
# 물
# 과
#  석
# 탑
# 이
#  유명
# 합니다
# .
#
#
#  -
#  **
# 석
# 굴
# 암
# **
# :
#  불
# 국
# 사
# 와
#  함께
#  유
# 네
# 스
# 코
#  세계
# 문화
# 유
# 산
# 으로
#  지정
# 된
#  석
# 굴
#  사
# 원
# 입니다
# .
#
#
# 4
# .
#  **
# 제
# 주
# 도
# **
# :
#
#
#  -
#  **
# 한
# 라
# 산
# **
# :
#  제주
# 도의
#  중심
# 에
#  위치
# 한
#  산
# 으로
# ,
#  등
# 산
# 과
#  자연
#  경
# 관
# 을
#  즐
# 길
#  수
#  있습니다
# .
#
#
#  -
#  **
# 성
# 산
# 일
# 출
# 봉
# **
# :
#  일
# 출
# 을
#  감
# 상
# 하기
#  좋은
#  장소
# 로
# ,
#  유
# 네
# 스
# 코
#  세계
# 자
# 연
# 유
# 산
# 으로
#  지정
# 되어
#  있습니다
# .
#
#
#  -
#  **
# 천
# 지
# 연
#  폭
# 포
# **
# :
#  아름
# 다운
#  폭
# 포
# 로
# ,
#  주변
#  경
# 관
# 이
#  매우
#  아름
# 답
# 습니다
# .
#
#
# 5
# .
#  **
# 전
# 주
# **
# :
#
#
#  -
#  **
# 전
# 주
#  한
# 옥
# 마
# 을
# **
# :
#  전
# 통
#  한
# 옥
# 이
#  잘
#  보
# 존
# 된
#  마
# 을
# 로
# ,
#  한국
# 의
#  전
# 통
#  문
# 화를
#  체
# 험
# 할
#  수
#  있습니다
# .
#
#
#  -
#  **
# 전
# 주
#  비
# 빔
# 밥
# **
# :
#  전
# 주의
#  대표
# 적인
#  음식
# 으로
# ,
#  다양한
#  재
# 료
# 가
#  어
# 우
# 러
# 진
#  맛
# 을
#  즐
# 길
#  수
#  있습니다
# .
#
#
# 이
#  외
# 에도
#  대한민국
# 에는
#  다양한
#  자연
#  경
# 관
# 과
#  문화
#  유
# 산
# 이
#  많
# 으
# 니
# ,
#  여행
#  계획
#  시
#  참고
# 하시
# 기
#  바랍니다
# .
